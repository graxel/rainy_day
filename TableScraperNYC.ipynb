# %%
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import selenium
from datetime import datetime
from datetime import timedelta
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
import csv
import random


def read_webpage(driver,url):
        
    driver.get(url)

    time.sleep(random.randint(5,12))
    xp = '//app/city-history/city-history-layout/div/div[2]/'\
            + 'section/div[2]/div[3]/div/div/div/div/'\
            + 'city-history-observation/div/div[2]/table/tbody'
    
    webpage_data = driver.find_element_by_xpath(xp)

    return webpage_data


chromedriver = '/Users/grazillionaire/Documents/chromedriver' # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

driver = webdriver.Chrome(chromedriver)


# Generate list of dates (months) to pull weather data for.

# For Chicago
#city = 'il/chicago/KORD'
#start_date = datetime(2017,5,1)
#end_date = datetime(2018,7,1)


# For New York
city = 'ny/new-york/KNYC'
start_date = datetime(2010,5,1)
end_date = datetime.today()

date_list = pd.Series(pd.date_range(start_date,end_date,freq='MS'))

for date in date_list:
    
    url = 'https://www.wunderground.com/history/monthly/us/{loc}/date/{y}-{m}?cm_ven=localwx_history'\
          .format(loc=city, y=date.year, m=date.month)
    
    # Record start time (for scraper performance purposes)
    start_time = datetime.now()
    webpage_data = read_webpage(driver, url)

    storage = open('NYC weather data/NYC-{y}-{m}.txt'\
                  .format(y=date.year, m=date.month), 'w')
    
    storage.write(webpage_data.text)
    
    stop_time = datetime.now()
    elapsed = stop_time-start_time

    print('New York weather data for ',date.month,'/',date.year,' scraped in ',
          elapsed.seconds + elapsed.microseconds/1000000, ' s', sep='')

driver.close()
# Out:
# New York weather data for 5/2010 scraped in 23.862709 s
# New York weather data for 6/2010 scraped in 25.684217 s
# New York weather data for 7/2010 scraped in 12.620076 s
# New York weather data for 8/2010 scraped in 56.100029 s
# New York weather data for 9/2010 scraped in 162.270352 s
# New York weather data for 10/2010 scraped in 8.317945 s
# New York weather data for 11/2010 scraped in 12.50968 s
# New York weather data for 12/2010 scraped in 39.609834 s
# New York weather data for 1/2011 scraped in 42.849312 s
# New York weather data for 2/2011 scraped in 35.798464 s
# New York weather data for 3/2011 scraped in 45.080511 s
# New York weather data for 4/2011 scraped in 42.843321 s
# New York weather data for 5/2011 scraped in 39.351397 s
# New York weather data for 6/2011 scraped in 41.705227 s
# New York weather data for 7/2011 scraped in 163.782859 s
# New York weather data for 8/2011 scraped in 12.467691 s
# New York weather data for 9/2011 scraped in 44.03534 s
# New York weather data for 10/2011 scraped in 12.203777 s
# New York weather data for 11/2011 scraped in 11.550425 s
# New York weather data for 12/2011 scraped in 6.863357 s
# New York weather data for 1/2012 scraped in 7.351246 s
# New York weather data for 2/2012 scraped in 7.235455 s
# New York weather data for 3/2012 scraped in 14.534203 s
# New York weather data for 4/2012 scraped in 7.880268 s
# New York weather data for 5/2012 scraped in 13.315996 s
# New York weather data for 6/2012 scraped in 86.714077 s
# New York weather data for 7/2012 scraped in 10.280369 s
# New York weather data for 8/2012 scraped in 41.124373 s
# New York weather data for 9/2012 scraped in 7.543589 s
# New York weather data for 10/2012 scraped in 9.730525 s
# New York weather data for 11/2012 scraped in 30.829025 s
# New York weather data for 12/2012 scraped in 39.870096 s
# New York weather data for 1/2013 scraped in 10.101142 s
# New York weather data for 2/2013 scraped in 6.836931 s
# New York weather data for 3/2013 scraped in 7.536342 s
# New York weather data for 4/2013 scraped in 7.099245 s
